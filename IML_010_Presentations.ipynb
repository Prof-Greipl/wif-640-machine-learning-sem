# %% [markdown]
# <a href="https://colab.research.google.com/github/Prof-Greipl/wif-640-machine-learning-sem/blob/master/IML_010_Presentations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Presentations in WIF640

# %% [markdown]
# ---
# ## (P1) Vectors & Matrix, Features and Labels with Phython Arrays

# %% [markdown]
# ## (P2) Pandas Dataframes and the AUTO-MPG Dataset

# %% [markdown]
# ## (P3) Matplotlib: Datavisualization

# %% [markdown]
# ## (P4) A single neuron and a network layer

# %% [markdown]
# ## (P5) A Neural Network

# %% [markdown]
# ## (P6) Forward Propagation

# %% [markdown]
# ## (P7) Backward Propagation and Training

# %% [markdown]
# ##  (P8) Visualization of Training Process

# %% [markdown]
# ## (P9) Early Stopping

# %% [markdown]
# ## (P10) Data Normalization

# %% [markdown]
# ## (P11) Case Study: AUTO-MPG

# %% [markdown]
# ## (P12) Training and Validation Data

# %% [markdown]
# ## (P13) AUTO-MPG with KERAS

# %% [markdown]
# ## (P17) Case Study: Handwritten Digits (MNIST)
